# %%
import numpy as np
import pandas as pd

frame = pd.read_excel('學生成績單.xlsx')
frame
# Out:
#     學號   姓名  國文   英文  數學   地理  歷史   總分    平均  排名
# 0   37  黃政甫  69   96  94   95  88  442  88.4   1
# 1   23  蔡至剛  98   84  81   91  75  429  85.8   2
# 2   40  龔姵君  98   71  86   66  97  418  83.6   3
# 3   48  鞠冠宇  83   93  61   92  87  416  83.2   4
# 4   47  許芳如  73   98  63   83  98  415  83.0   5
# 5    4  周家銘  71   90  91   95  64  411  82.2   6
# 6   50  黃名明  69   64  86   96  92  407  81.4   7
# 7   17  李淑芳  94  100  79   50  83  406  81.2   8
# 8   12  郭致恬  86   76  93   95  52  402  80.4   9
# 9   24  黃詩妃  81   86  97   69  66  399  79.8  10
# 10   9  朱惠儀  64   65  92   75  99  395  79.0  11
# 11  18  陳冠竹  86   93  67   68  79  393  78.6  12
# 12  16  陳向愛  71   85  73   63  99  391  78.2  13
# 13  32  蔡孟泉  67   79  90   69  84  389  77.8  14
# 14  13  吳明妮  92   67  97   52  81  389  77.8  14
# 15   8  劉佳佩  73   99  85   54  75  386  77.2  16
# 16  27  王坤安  65   51  81   96  92  385  77.0  17
# 17  26  李政成  62   91  98   82  52  385  77.0  17
# ...

# %%
def grade(v):
    if v >= 80:
        return '優'
    elif v >= 70:
        return '甲'
    elif v >= 60:
        return '乙'
    else:
        return '丙'


frame['等級'] = frame['平均'].map(grade)

# %%
frame
# Out:
#     學號   姓名  國文   英文  數學   地理  歷史   總分    平均  排名 等級
# 0   37  黃政甫  69   96  94   95  88  442  88.4   1  優
# 1   23  蔡至剛  98   84  81   91  75  429  85.8   2  優
# 2   40  龔姵君  98   71  86   66  97  418  83.6   3  優
# 3   48  鞠冠宇  83   93  61   92  87  416  83.2   4  優
# 4   47  許芳如  73   98  63   83  98  415  83.0   5  優
# 5    4  周家銘  71   90  91   95  64  411  82.2   6  優
# 6   50  黃名明  69   64  86   96  92  407  81.4   7  優
# 7   17  李淑芳  94  100  79   50  83  406  81.2   8  優
# 8   12  郭致恬  86   76  93   95  52  402  80.4   9  優
# 9   24  黃詩妃  81   86  97   69  66  399  79.8  10  甲
# 10   9  朱惠儀  64   65  92   75  99  395  79.0  11  甲
# 11  18  陳冠竹  86   93  67   68  79  393  78.6  12  甲
# 12  16  陳向愛  71   85  73   63  99  391  78.2  13  甲
# 13  32  蔡孟泉  67   79  90   69  84  389  77.8  14  甲
# 14  13  吳明妮  92   67  97   52  81  389  77.8  14  甲
# 15   8  劉佳佩  73   99  85   54  75  386  77.2  16  甲
# 16  27  王坤安  65   51  81   96  92  385  77.0  17  甲
# ...

# %%
frame1 = frame[['國文','英文','數學','地理','歷史']]
frame1
# Out:
#     國文   英文  數學   地理  歷史
# 0   69   96  94   95  88
# 1   98   84  81   91  75
# 2   98   71  86   66  97
# 3   83   93  61   92  87
# 4   73   98  63   83  98
# 5   71   90  91   95  64
# 6   69   64  86   96  92
# 7   94  100  79   50  83
# 8   86   76  93   95  52
# 9   81   86  97   69  66
# 10  64   65  92   75  99
# 11  86   93  67   68  79
# 12  71   85  73   63  99
# 13  67   79  90   69  84
# 14  92   67  97   52  81
# 15  73   99  85   54  75
# 16  65   51  81   96  92
# 17  62   91  98   82  52
# 18  96   72  66   76  73
# 19  67   81  77   81  72
# 20  68   65  98   96  51
# 21  60   93  91   81  51
# 22  59   85  74  100  56
# 23  94   86  55   80  59
# 24  71   73  77   85  65
# 25  68   97  92   63  50
# 26  74   85  60  100  50
# 27  65   78  71   97  57
# 28  71   77  73   52  93
# 29  85   75  65   79  61
# 30  53   91  78   83  58
# 31  79   93  62   56  71
# 32  77   68  99   54  61
# 33  75   63  50   99  72
# 34  73   67  57   71  90
# 35  73   68  70   52  92
# ...

# %%
def fun1(s):    
    return s.std()
frame1.apply(fun1)
# Out:
# 國文    12.432676
# 英文    13.687012
# 數學    14.581803
# 地理    15.735881
# 歷史    15.380627
# dtype: float64
