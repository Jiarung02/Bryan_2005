# %%
import pandas as pd
data = {"字串":["台北", "台中"],
        "整數":[1000, 3000],
        "浮點數":[3.258, 7.396]}

df = pd.DataFrame(data)
display(df)
# Out:
#    字串    整數    浮點數
# 0  台北  1000  3.258
# 1  台中  3000  7.396

# %%
#視覺美化資料表
#pip install jinja2
df.style\
.format(precision=2,thousands=",",decimal=".")\
.relabel_index(["列1","列2"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       1 #視覺美化資料表
#       2 #pip install jinja2
#       3 df.style\
#       4 .format(precision=2,thousands=",",decimal=".")\
# ----> 5 .relabel_index(["列1","列2"])
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/style_render.py:1536, in StylerRenderer.relabel_index(self, labels, axis, level)
#    1534 visible_len = len(obj) - len(set(hidden_labels))
#    1535 if len(labels) != visible_len:
# -> 1536     raise ValueError(
#    1537         "``labels`` must be of length equal to the number of "
#    1538         f"visible labels along ``axis`` ({visible_len})."
#    1539     )
#    1541 if level is None:
#    1542     level = [i for i in range(obj.nlevels) if not hidden_lvls[i]]
#
# ValueError: ``labels`` must be of length equal to the number of visible labels along ``axis`` (5).

# %%
import numpy as np
data = np.random.rand(10,2) * 5
df = pd.DataFrame(data,
                  index = pd.date_range(start="2023-09-01",periods=10),
                  columns=["台北","台中"]
                  )
df
# Out:
#                   台北        台中
# 2023-09-01  4.523368  0.886435
# 2023-09-02  3.171218  2.451818
# 2023-09-03  4.820789  1.607189
# 2023-09-04  4.279625  4.145066
# 2023-09-05  3.184750  0.131627
# 2023-09-06  3.333484  3.695260
# 2023-09-07  2.444687  1.732277
# 2023-09-08  0.269154  1.328165
# 2023-09-09  1.871807  2.807763
# 2023-09-10  0.922600  1.769324

# %%
#視覺美化資料表
def feel_condition(v):
    if v < 1.75:
        return "溫暖"
    elif v < 2.75:
        return "潮溼"
    else:
        return "日照"
    
df.style\
.format(feel_condition)\
.set_caption("體感溫度")\
.background_gradient(cmap="PuBuGn",vmin=1,vmax=5,axis=None)
# Out:
# <style type="text/css">
# #T_aad15_row0_col0 {
#   background-color: #016a57;
#   color: #f1f1f1;
# }
# #T_aad15_row0_col1, #T_aad15_row4_col1, #T_aad15_row7_col0, #T_aad15_row9_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_aad15_row1_col0 {
#   background-color: #57a1ca;
#   color: #f1f1f1;
# }
# #T_aad15_row1_col1, #T_aad15_row6_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_aad15_row2_col0 {
#   background-color: #015342;
#   color: #f1f1f1;
# }
# #T_aad15_row2_col1 {
#   background-color: #e7dfee;
#   color: #000000;
# }
# #T_aad15_row3_col0 {
#   background-color: #01756f;
#   color: #f1f1f1;
# }
# #T_aad15_row3_col1 {
#   background-color: #027b7b;
#   color: #f1f1f1;
# }
# #T_aad15_row4_col0 {
#   background-color: #55a0ca;
#   color: #f1f1f1;
# }
# #T_aad15_row5_col0 {
#   background-color: #4698c5;
#   color: #f1f1f1;
# }
# #T_aad15_row5_col1 {
#   background-color: #218aab;
#   color: #f1f1f1;
# }
# #T_aad15_row6_col1 {
#   background-color: #e0daec;
#   color: #000000;
# }
# #T_aad15_row7_col1 {
#   background-color: #f2e9f4;
#   color: #000000;
# }
# #T_aad15_row8_col0 {
#   background-color: #d8d6e9;
#   color: #000000;
# }
# #T_aad15_row8_col1 {
#   background-color: #80b1d4;
#   color: #f1f1f1;
# }
# #T_aad15_row9_col1 {
#   background-color: #ddd9eb;
#   color: #000000;
# }
# </style>
# <table id="T_aad15">
#   <caption>體感溫度</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aad15_level0_col0" class="col_heading level0 col0" >台北</th>
#       <th id="T_aad15_level0_col1" class="col_heading level0 col1" >台中</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aad15_level0_row0" class="row_heading level0 row0" >2023-09-01 00:00:00</th>
#       <td id="T_aad15_row0_col0" class="data row0 col0" >日照</td>
#       <td id="T_aad15_row0_col1" class="data row0 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_aad15_level0_row1" class="row_heading level0 row1" >2023-09-02 00:00:00</th>
#       <td id="T_aad15_row1_col0" class="data row1 col0" >日照</td>
#       <td id="T_aad15_row1_col1" class="data row1 col1" >潮溼</td>
#     </tr>
#     <tr>
#       <th id="T_aad15_level0_row2" class="row_heading level0 row2" >2023-09-03 00:00:00</th>
#       <td id="T_aad15_row2_col0" class="data row2 col0" >日照</td>
#       <td id="T_aad15_row2_col1" class="data row2 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_aad15_level0_row3" class="row_heading level0 row3" >2023-09-04 00:00:00</th>
#       <td id="T_aad15_row3_col0" class="data row3 col0" >日照</td>
#       <td id="T_aad15_row3_col1" class="data row3 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_aad15_level0_row4" class="row_heading level0 row4" >2023-09-05 00:00:00</th>
#       <td id="T_aad15_row4_col0" class="data row4 col0" >日照</td>
#       <td id="T_aad15_row4_col1" class="data row4 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_aad15_level0_row5" class="row_heading level0 row5" >2023-09-06 00:00:00</th>
#       <td id="T_aad15_row5_col0" class="data row5 col0" >日照</td>
#       <td id="T_aad15_row5_col1" class="data row5 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_aad15_level0_row6" class="row_heading level0 row6" >2023-09-07 00:00:00</th>
#       <td id="T_aad15_row6_col0" class="data row6 col0" >潮溼</td>
#       <td id="T_aad15_row6_col1" class="data row6 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_aad15_level0_row7" class="row_heading level0 row7" >2023-09-08 00:00:00</th>
#       <td id="T_aad15_row7_col0" class="data row7 col0" >溫暖</td>
#       <td id="T_aad15_row7_col1" class="data row7 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_aad15_level0_row8" class="row_heading level0 row8" >2023-09-09 00:00:00</th>
#       <td id="T_aad15_row8_col0" class="data row8 col0" >潮溼</td>
#       <td id="T_aad15_row8_col1" class="data row8 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_aad15_level0_row9" class="row_heading level0 row9" >2023-09-10 00:00:00</th>
#       <td id="T_aad15_row9_col0" class="data row9 col0" >溫暖</td>
#       <td id="T_aad15_row9_col1" class="data row9 col1" >潮溼</td>
#     </tr>
#   </tbody>
# </table>

# %%
#隱藏資料
df = pd.DataFrame(np.random.randn(5,5))
df.style\
.hide(subset=[0, 2, 4],axis=0)\
.hide(subset=[1,3],axis=1)

#0是橫軸 1是直的
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e76b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e76b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6e76b_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_6e76b_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e76b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e76b_row1_col0" class="data row1 col0" >-0.296393</td>
#       <td id="T_6e76b_row1_col2" class="data row1 col2" >0.009125</td>
#       <td id="T_6e76b_row1_col4" class="data row1 col4" >2.020223</td>
#     </tr>
#     <tr>
#       <th id="T_6e76b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e76b_row3_col0" class="data row3 col0" >-0.006578</td>
#       <td id="T_6e76b_row3_col2" class="data row3 col2" >0.787533</td>
#       <td id="T_6e76b_row3_col4" class="data row3 col4" >-0.611564</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.DataFrame(np.random.randn(10,4),
             columns=["A", "B", "C", "D"])
display(df)

def style_negative(v, props=''):
    return props if v < 0 else None

df.style\
.map(style_negative,props='color:red;')
# Out:
#           A         B         C         D
# 0 -0.405003 -0.178881  2.054176  1.836214
# 1 -0.272445 -0.753342  0.579720  0.306885
# 2 -1.401986 -0.160193  2.047401  0.353075
# 3 -0.086258 -0.368037 -1.968116 -0.066691
# 4 -0.449862  1.246609  0.787806 -0.015966
# 5 -1.305322  2.754181 -0.777488  0.868871
# 6 -1.426261  1.463956 -1.287755  0.034208
# 7  0.638016 -0.727606  0.265960 -0.933521
# 8  0.617619 -0.296383  0.462196 -0.108953
# 9 -0.057066 -0.023687  0.579709 -0.350362
# <style type="text/css">
# #T_7f1c0_row0_col0, #T_7f1c0_row0_col1, #T_7f1c0_row1_col0, #T_7f1c0_row1_col1, #T_7f1c0_row2_col0, #T_7f1c0_row2_col1, #T_7f1c0_row3_col0, #T_7f1c0_row3_col1, #T_7f1c0_row3_col2, #T_7f1c0_row3_col3, #T_7f1c0_row4_col0, #T_7f1c0_row4_col3, #T_7f1c0_row5_col0, #T_7f1c0_row5_col2, #T_7f1c0_row6_col0, #T_7f1c0_row6_col2, #T_7f1c0_row7_col1, #T_7f1c0_row7_col3, #T_7f1c0_row8_col1, #T_7f1c0_row8_col3, #T_7f1c0_row9_col0, #T_7f1c0_row9_col1, #T_7f1c0_row9_col3 {
#   color: red;
# }
# </style>
# <table id="T_7f1c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f1c0_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7f1c0_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_7f1c0_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_7f1c0_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f1c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f1c0_row0_col0" class="data row0 col0" >-0.405003</td>
#       <td id="T_7f1c0_row0_col1" class="data row0 col1" >-0.178881</td>
#       <td id="T_7f1c0_row0_col2" class="data row0 col2" >2.054176</td>
#       <td id="T_7f1c0_row0_col3" class="data row0 col3" >1.836214</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f1c0_row1_col0" class="data row1 col0" >-0.272445</td>
#       <td id="T_7f1c0_row1_col1" class="data row1 col1" >-0.753342</td>
#       <td id="T_7f1c0_row1_col2" class="data row1 col2" >0.579720</td>
#       <td id="T_7f1c0_row1_col3" class="data row1 col3" >0.306885</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f1c0_row2_col0" class="data row2 col0" >-1.401986</td>
#       <td id="T_7f1c0_row2_col1" class="data row2 col1" >-0.160193</td>
#       <td id="T_7f1c0_row2_col2" class="data row2 col2" >2.047401</td>
#       <td id="T_7f1c0_row2_col3" class="data row2 col3" >0.353075</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f1c0_row3_col0" class="data row3 col0" >-0.086258</td>
#       <td id="T_7f1c0_row3_col1" class="data row3 col1" >-0.368037</td>
#       <td id="T_7f1c0_row3_col2" class="data row3 col2" >-1.968116</td>
#       <td id="T_7f1c0_row3_col3" class="data row3 col3" >-0.066691</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f1c0_row4_col0" class="data row4 col0" >-0.449862</td>
#       <td id="T_7f1c0_row4_col1" class="data row4 col1" >1.246609</td>
#       <td id="T_7f1c0_row4_col2" class="data row4 col2" >0.787806</td>
#       <td id="T_7f1c0_row4_col3" class="data row4 col3" >-0.015966</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7f1c0_row5_col0" class="data row5 col0" >-1.305322</td>
#       <td id="T_7f1c0_row5_col1" class="data row5 col1" >2.754181</td>
#       <td id="T_7f1c0_row5_col2" class="data row5 col2" >-0.777488</td>
#       <td id="T_7f1c0_row5_col3" class="data row5 col3" >0.868871</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7f1c0_row6_col0" class="data row6 col0" >-1.426261</td>
#       <td id="T_7f1c0_row6_col1" class="data row6 col1" >1.463956</td>
#       <td id="T_7f1c0_row6_col2" class="data row6 col2" >-1.287755</td>
#       <td id="T_7f1c0_row6_col3" class="data row6 col3" >0.034208</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7f1c0_row7_col0" class="data row7 col0" >0.638016</td>
#       <td id="T_7f1c0_row7_col1" class="data row7 col1" >-0.727606</td>
#       <td id="T_7f1c0_row7_col2" class="data row7 col2" >0.265960</td>
#       <td id="T_7f1c0_row7_col3" class="data row7 col3" >-0.933521</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7f1c0_row8_col0" class="data row8 col0" >0.617619</td>
#       <td id="T_7f1c0_row8_col1" class="data row8 col1" >-0.296383</td>
#       <td id="T_7f1c0_row8_col2" class="data row8 col2" >0.462196</td>
#       <td id="T_7f1c0_row8_col3" class="data row8 col3" >-0.108953</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7f1c0_row9_col0" class="data row9 col0" >-0.057066</td>
#       <td id="T_7f1c0_row9_col1" class="data row9 col1" >-0.023687</td>
#       <td id="T_7f1c0_row9_col2" class="data row9 col2" >0.579709</td>
#       <td id="T_7f1c0_row9_col3" class="data row9 col3" >-0.350362</td>
#     </tr>
#   </tbody>
# </table>
