# %%
#讀取csv檔成為2維的list
import csv
with open('bb.csv',encoding='utf-8',newline='') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)
    #print(type(csv_reader))
    csv_list = list(csv_reader)
display(csv_list)
# Out:
# [['溫法堯', '86', '58', '57', '66', '71'],
#  ['葉志峰', '88', '92', '56', '50', '98'],
#  ['葉軍仰', '83', '68', '57', '78', '89'],
#  ['劉嘉泰', '73', '88', '95', '93', '76'],
#  ['王筱婷', '71', '57', '80', '89', '85'],
#  ['鄭淑珍', '92', '75', '67', '93', '51'],
#  ['楊火帆', '58', '84', '81', '88', '58'],
#  ['趙偉銘', '81', '50', '95', '95', '89'],
#  ['謝南慧', '86', '56', '54', '63', '52'],
#  ['謝哲維', '56', '52', '88', '88', '72'],
#  ['鄭琇亞', '68', '97', '93', '88', '64'],
#  ['陳家年', '98', '50', '87', '80', '73'],
#  ['陳筱涵', '93', '90', '92', '81', '98'],
#  ['白美珍', '89', '65', '96', '71', '53'],
#  ['陳倩潔', '92', '99', '86', '62', '95'],
#  ['李進慧', '88', '62', '91', '87', '58'],
#  ['陳淑萍', '66', '76', '79', '94', '90'],
#  ['朱惠儀', '66', '51', '98', '96', '53'],
#  ['劉嘉泰', '68', '90', '79', '95', '55'],
#  ['鄧哲榮', '53', '89', '91', '68', '98'],
#  ['黃雅慧', '67', '95', '84', '85', '74'],
#  ['陳怡珊', '84', '75', '65', '88', '89'],
#  ['張韋成', '78', '83', '94', '69', '72'],
# ...

# %%
for student in csv_list:
    if student[0] == '許芳如': #0是編碼（姓名）
        print(student)
        break
# Out:
# ['許芳如', '96', '83', '55', '85', '69']
