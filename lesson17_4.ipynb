# %%
import pandas as pd
df = pd.read_csv('學生成績.csv')
df
# Out:
#     學號   姓名  國文   英文  數學   地理  歷史   總分    平均
# 0    1  方筠紹  67   81  77   81  72  378  75.6
# 1    2  蔡世馨  68   65  98   96  51  378  75.6
# 2    3  黃佩芬  79   73  61   54  72  339  67.8
# 3    4  周家銘  71   90  91   95  64  411  82.2
# 4    5  林建勳  69   51  67   56  70  313  62.6
# 5    6  陳向愛  74   85  60  100  50  369  73.8
# 6    7  陳得映  73   94  66   65  53  351  70.2
# 7    8  劉佳佩  73   99  85   54  75  386  77.2
# 8    9  朱惠儀  64   65  92   75  99  395  79.0
# 9   10  錢佩豪  68   97  92   63  50  370  74.0
# 10  11  陳奇瑄  76   66  70   71  57  340  68.0
# 11  12  郭致恬  86   76  93   95  52  402  80.4
# 12  13  吳明妮  92   67  97   52  81  389  77.8
# 13  14  王德城  65   78  71   97  57  368  73.6
# 14  15  黃志福  73   67  57   71  90  358  71.6
# 15  16  陳向愛  71   85  73   63  99  391  78.2
# 16  17  李淑芳  94  100  79   50  83  406  81.2
# 17  18  陳冠竹  86   93  67   68  79  393  78.6
# 18  19  簡國瑋  51   50  99   79  55  334  66.8
# 19  20  郭淑真  72   68  58   92  60  350  70.0
# ...

# %%
df[["姓名", "國文", "英文", "數學"]]
# Out:
#      姓名  國文   英文  數學
# 0   方筠紹  67   81  77
# 1   蔡世馨  68   65  98
# 2   黃佩芬  79   73  61
# 3   周家銘  71   90  91
# 4   林建勳  69   51  67
# 5   陳向愛  74   85  60
# 6   陳得映  73   94  66
# 7   劉佳佩  73   99  85
# 8   朱惠儀  64   65  92
# 9   錢佩豪  68   97  92
# 10  陳奇瑄  76   66  70
# 11  郭致恬  86   76  93
# 12  吳明妮  92   67  97
# 13  王德城  65   78  71
# 14  黃志福  73   67  57
# 15  陳向愛  71   85  73
# 16  李淑芳  94  100  79
# 17  陳冠竹  86   93  67
# 18  簡國瑋  51   50  99
# 19  郭淑真  72   68  58
# 20  黃淑芬  71   73  77
# 21  黃政甫  75   63  50
# 22  蔡至剛  98   84  81
# 23  黃詩妃  81   86  97
# 24  黃佩玲  59   85  74
# 25  李政成  62   91  98
# 26  王坤安  65   51  81
# 27  黃旻林  77   68  99
# 28  羅佩樺  98   83  56
# 29  翁羽威  94   86  55
# 30  聶心怡  89   52  79
# 31  蔡孟泉  67   79  90
# 32  張牧聿  79   93  62
# 33  元延辛  85   75  65
# 34  陳樂紫  73   66  72
# 35  方筠紹  51   72  52
# 36  黃政甫  69   96  94
# 37  王德城  96   72  66
# 38  陳文賢  53   91  78
# 39  龔姵君  98   71  86
# 40  林怡偉  63   63  54
# 41  陳怡珊  71   77  73
# ...

# %%
#iloc[]
#loc[]
df.iloc[0]
# Out:
# 學號       1
# 姓名     方筠紹
# 國文      67
# 英文      81
# 數學      77
# 地理      81
# 歷史      72
# 總分     378
# 平均    75.6
# Name: 0, dtype: object

# %%
df.iloc[[0, 3, 5]]
# Out:
#    學號   姓名  國文  英文  數學   地理  歷史   總分    平均
# 0   1  方筠紹  67  81  77   81  72  378  75.6
# 3   4  周家銘  71  90  91   95  64  411  82.2
# 5   6  陳向愛  74  85  60  100  50  369  73.8

# %%
df.iloc[0:6]
# Out:
#    學號   姓名  國文  英文  數學   地理  歷史   總分    平均
# 0   1  方筠紹  67  81  77   81  72  378  75.6
# 1   2  蔡世馨  68  65  98   96  51  378  75.6
# 2   3  黃佩芬  79  73  61   54  72  339  67.8
# 3   4  周家銘  71  90  91   95  64  411  82.2
# 4   5  林建勳  69  51  67   56  70  313  62.6
# 5   6  陳向愛  74  85  60  100  50  369  73.8

# %%
#同時要欄和列
#iloc[],loc[]
df.iloc[:5,[0,1,3]]
# Out:
#    學號   姓名  英文
# 0   1  方筠紹  81
# 1   2  蔡世馨  65
# 2   3  黃佩芬  73
# 3   4  周家銘  90
# 4   5  林建勳  51
